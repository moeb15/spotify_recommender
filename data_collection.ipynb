# %% [markdown]
# ### In this notebook we obtain the data and export it to our database

# %%
import pandas as pd
import psycopg2
import os 
import time
from dotenv import load_dotenv
from sqlalchemy import create_engine
from utils.spotify_utils import get_token, get_genres, spotify_search

load_dotenv()

DB_NAME = os.getenv('DB_NAME')
DB_PASS = os.getenv('DB_PASS')

# %% [markdown]
# There are 50 artists per page and we'd like to scrape the first 10 pages,
# so in total for each genre we should have atmost 500 artists if there is no
# overlap, which is most likely not the case

# %%
token = get_token()
genres = get_genres(token)
MAX_PAGE = 10

artist_genres = {}
time_count = 0
for genre in genres:
    time_count += 30
    for i in range(MAX_PAGE):
        artist_genres.update(spotify_search(token,genre,i))
    time.sleep(30)
    if time_count == 3600:
        time_count = 0
        token = get_token()

artist_genres
# Out:
# {'Jason Mraz': ['acoustic pop', 'dance pop', 'neo mellow', 'pop'],
#  'The Paper Kites': ['acoustic pop',
#   'australian indie folk',
#   'indie folk',
#   'stomp and holler'],
#  'Brandi Carlile': ['acoustic pop',
#   'ectofolk',
#   'folk',
#   'lilith',
#   'modern folk rock',
#   'new americana'],
#  'Ray LaMontagne': ['acoustic pop',
#   'indie folk',
#   'neo mellow',
#   'stomp and holler'],
#  'Zack Tabudlo': ['acoustic opm', 'opm', 'p-pop'],
#  'Boyce Avenue': ['acoustic cover', 'neo mellow', 'viral pop'],
#  'Sara Bareilles': ['acoustic pop',
#   'lilith',
#   'neo mellow',
#   'pop rock',
#   'post-teen pop'],
#  'Kina Grannis': ['acoustic pop', 'viral pop'],
#  'Iron & Wine': ['acoustic pop',
#   'chamber pop',
#   'indie folk',
#   'indie rock',
#   'stomp and holler'],
#  'Amos Lee': ['acoustic pop', 'neo mellow', 'stomp and holler'],
#  'Chord Overstreet': ['acoustic pop'],
#  'Eddie Vedder': ['acoustic rock', 'grunge', 'permanent wave'],
#  'Drew Holcomb & The Neighbors': ['acoustic pop', 'stomp and holler'],
#  'Joy Williams': ['acoustic pop',
#   'christian indie',
#   'nashville americana',
#   'nashville singer-songwriter',
#   'new americana'],
#  'Ingrid Michaelson': ['acoustic pop', 'ectofolk', 'lilith', 'neo mellow'],
#  'Violent Femmes': ['acoustic punk', 'alternative rock'],
#  'Ben Rector': ['acoustic pop',
#   'indiecoustica',
#   'lds youth',
#   'neo mellow',
#   'piano rock'],
#  'Andrew Belle': ['acoustic pop'],
#  'Ichiko Aoba': ['j-acoustic'],
#  'Matt Nathanson': ['acoustic pop', 'neo mellow'],
#  'The Mayries': ['acoustic cover', 'acoustic pop'],
#  'Joshua Hyslop': ['acoustic pop', 'indiecoustica'],
#  'Jonah Baker': ['acoustic cover'],
#  'The Civil Wars': ['acoustic pop',
#   'indie folk',
#   'neo mellow',
#   'new americana',
#   'stomp and holler'],
#  'Penny and Sparrow': ['acoustic pop',
#   'indie folk',
#   'indiecoustica',
#   'stomp and holler'],
#  'Mat Kearney': ['acoustic pop', 'neo mellow'],
#  'Guus Dielissen': ['acoustic guitar cover'],
#  'Howie Day': ['acoustic pop', 'neo mellow', 'pop rock'],
#  'Damien Rice': ['acoustic pop',
#   'irish rock',
#   'irish singer-songwriter',
#   'neo mellow',
#   'singer-songwriter'],
#  'AJJ': ['acoustic punk', 'anti-folk', 'folk punk', 'pov: indie'],
#  'Frank Turner': ['acoustic rock', 'folk punk'],
#  'Joseph Sullinger': ['acoustic guitar cover'],
#  'Gabrielle Aplin': ['acoustic pop',
#   'neo-singer-songwriter',
#   'uk pop',
#   'viral pop'],
#  'Joshua Radin': ['acoustic pop', 'neo mellow'],
#  'The Weepies': ['acoustic pop', 'ectofolk', 'neo mellow'],
#  'Taj Mahal': ['acoustic blues',
#   'blues',
#   'country blues',
#   'folk',
#   'harmonica blues',
#   'jazz blues',
#   'modern blues',
#   'traditional blues'],
#  'Peter Bradley Adams': ['acoustic pop'],
#  'Brett Dennen': ['acoustic pop', 'neo mellow'],
#  'Gen Hoshino': ['j-acoustic', 'j-pop', 'japanese singer-songwriter'],
#  'Alexi Murdoch': ['acoustic pop', 'british singer-songwriter', 'indie folk'],
#  'Eric Hutchinson': ['acoustic pop', 'neo mellow'],
#  'Megan Davies': ['acoustic cover'],
#  'Canyon City': ['acoustic pop', 'indiecoustica'],
#  'William Fitzsimmons': ['acoustic pop', 'indie folk'],
#  'Matt Johnson': ['acoustic cover'],
#  "Keb' Mo'": ['acoustic blues',
#   'blues',
#   'country blues',
#   'electric blues',
#   'modern blues',
#   'piedmont blues'],
#  'Parachute': ['acoustic pop',
#   'charlottesville indie',
#   'neo mellow',
#   'neon pop punk',
#   'pop rock',
#   'viral pop'],
#  'Marc Broussard': ['acoustic pop', 'lafayette indie'],
#  'Bailey Jehl': ['acoustic chill'],
#  'John Frusciante': ['acoustic rock'],
#  'Agustín Amigó': ['instrumental acoustic guitar'],
#  "Howlin' Wolf": ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'delta blues',
#   'harmonica blues',
#   'memphis blues',
#   'traditional blues'],
#  'Tyler Ward': ['acoustic cover', 'viral pop'],
#  'Noah Gundersen': ['acoustic pop',
#   'alternative roots rock',
#   'indie folk',
#   'stomp and holler'],
#  'Edy Hafler': ['acoustic guitar cover'],
#  'Rodrigo y Gabriela': ['acoustic rock', 'world'],
#  'Benjamin Francis Leftwich': ['acoustic pop',
#   'indie anthem-folk',
#   'indie folk',
#   'stomp and holler',
#   'york indie'],
#  'Days N Daze': ['acoustic punk', 'folk punk', 'texas punk'],
#  'Georg Erixon': ['acoustic guitar cover'],
#  'Madi Diaz': ['acoustic pop'],
#  'Aimyon': ['j-acoustic', 'j-pop'],
#  'Amber Leigh Irish': ['acoustic cover'],
#  'Denis Turbide': ['instrumental acoustic guitar'],
#  'Anna Nalick': ['acoustic pop', 'ectofolk', 'lilith', 'neo mellow'],
#  'Bailey Rushlow': ['acoustic cover'],
#  'John Adams': ['21st century classical',
#   'american contemporary classical',
#   'classical',
#   'compositional ambient',
#   'contemporary classical',
#   'minimalism',
#   'post-minimalism'],
#  'The Moon Loungers': ['acoustic cover'],
#  'Johnnyswim': ['acoustic pop', 'folk-pop'],
#  'Drew Holcomb': ['acoustic pop', 'indiecoustica'],
#  'Sara Farell': ['acoustic cover'],
#  'Kurt Cobain': ['acoustic rock', 'grunge'],
#  'Eden Elf': ['acoustic cover'],
#  'Augustana': ['acoustic pop', 'neo mellow', 'piano rock', 'pop rock'],
#  'Sonny Boy Williamson II': ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'country blues',
#   'delta blues',
#   'harmonica blues',
#   'traditional blues'],
#  'Covers Culture': ['acoustic cover'],
#  'Adam Christopher': ['acoustic cover'],
#  'Steve Petrunak': ['acoustic guitar cover', 'classify'],
#  'Erato': ['acoustic cover', 'pop folk'],
#  'Ben Woodward': ['acoustic chill'],
#  'Phillip LaRue': ['acoustic pop', 'indiecoustica'],
#  'Colin & Caroline': ['acoustic cover'],
#  'Angel Taylor': ['acoustic pop'],
#  'Jaclyn Davies': ['acoustic chill'],
#  'Jack Savoretti': ['acoustic pop'],
#  'Eric Lumiere': ['acoustic cover'],
#  'Harley Poe': ['acoustic punk', 'folk punk'],
#  'Tyrone Wells': ['acoustic pop', 'neo mellow'],
#  'Chris Smither': ['acoustic blues',
#   'country blues',
#   'folk',
#   'new england americana'],
#  'Julia Ross': ['acoustic chill'],
#  'Roses & Frey': ['acoustic cover'],
#  'Albert Collins': ['acoustic blues',
#   'blues',
#   'blues rock',
#   'british blues',
#   'electric blues',
#   'modern blues',
#   'texas blues',
#   'traditional blues'],
#  'Greg Laswell': ['acoustic pop'],
#  'Jennel Garcia': ['acoustic cover'],
#  'Priscilla Ahn': ['acoustic pop', 'anime score', 'ectofolk'],
#  'Acoustic Guitar Collective': ['acoustic guitar cover'],
#  'Kaiak': ['acoustic chill'],
#  'Landon Pigg': ['acoustic pop'],
#  'Jon Foreman': ['acoustic pop', 'christian uplift'],
#  'Bo Diddley': ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'electric blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'traditional blues'],
#  'Mark Lanegan': ['acoustic rock', 'garage rock', 'palm desert scene'],
#  'Link Wray': ['acoustic blues',
#   'classic garage rock',
#   'cosmic american',
#   'garage rock',
#   'native american',
#   'surf music'],
#  'Vendredi': ['acoustic cover'],
#  'Casper Esmann': ['acoustic guitar cover', 'instrumental acoustic guitar'],
#  'Front Porch Step': ['acoustic rock'],
#  'Thomas Daniel': ['acoustic cover'],
#  'Slim Harpo': ['acoustic blues',
#   'blues',
#   'harmonica blues',
#   'louisiana blues',
#   'swamp blues',
#   'swamp rock',
#   'traditional blues'],
#  'R.L. Burnside': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'Jon McLaughlin': ['acoustic pop', 'indy indie', 'neo mellow', 'piano rock'],
#  'Alan Shoesmith': ['instrumental acoustic guitar'],
#  'Dan Berk': ['acoustic chill'],
#  'Lúc': ['acoustic chill'],
#  'Eric Bibb': ['acoustic blues',
#   'country blues',
#   'modern blues',
#   'piedmont blues'],
#  "Panucci's Pizza": ['acoustic rock', 'lo-fi indie'],
#  'Lusaint': ['acoustic chill', 'acoustic cover'],
#  'Pigeon Pit': ['acoustic punk', 'folk punk', 'pov: indie'],
#  'The Bridge City Sinners': ['acoustic punk', 'portland punk'],
#  'Callum J Wright': ['acoustic cover'],
#  'Robert Johnson': ['acoustic blues',
#   'blues',
#   'delta blues',
#   'pre-war blues',
#   'traditional blues'],
#  'Susie Suh': ['acoustic pop', 'oth indie'],
#  "Tow'rs": ['acoustic pop', 'indie folk', 'indiecoustica', 'stomp and holler'],
#  'Daniel Robinson': ['acoustic cover'],
#  'Motohiro Hata': ['j-acoustic',
#   'j-pop',
#   'j-rock',
#   'japanese singer-songwriter'],
#  'Clementine Duo': ['acoustic cover'],
#  'Chuck Ragan': ['acoustic punk', 'folk punk'],
#  "Lightnin' Hopkins": ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'texas blues',
#   'traditional blues'],
#  'Liad Abraham': ['acoustic guitar cover', 'israeli folk'],
#  "Mother's Daughter": ['acoustic chill'],
#  'Defiance, Ohio': ['acoustic punk', 'columbus ohio indie', 'folk punk'],
#  'Ross Copperman': ['acoustic pop', 'piano rock'],
#  'Joe Purdy': ['acoustic pop',
#   'arkansas country',
#   'indie folk',
#   'neo mellow',
#   'stomp and flutter'],
#  'Dave Barnes': ['acoustic pop', 'neo mellow'],
#  'Andrew Foy': ['acoustic guitar cover'],
#  'Steve Moakler': ['acoustic pop'],
#  'Whalebone': ['instrumental acoustic guitar'],
#  'A Fine Frenzy': ['acoustic pop', 'lilith', 'neo mellow'],
#  'August Flendahl': ['instrumental acoustic guitar'],
#  'Elgafar': ['instrumental acoustic guitar'],
#  'Sungha Jung': ['acoustic guitar cover', 'fingerstyle', 'viral pop'],
#  "Hannah's Yard": ['acoustic cover'],
#  'Son&Dad': ['acoustic cover'],
#  'Mischief Brew': ['acoustic punk', 'folk punk', 'gypsy punk', 'philly indie'],
#  'Plamina': ['acoustic cover'],
#  'Rachael Yamagata': ['acoustic pop', 'lilith'],
#  'Jillian Edwards': ['acoustic pop', 'indiecoustica'],
#  'Jason Reeves': ['acoustic pop', 'neo mellow'],
#  'Sandra McCracken': ['acoustic pop', 'christian indie', 'roots worship'],
#  'Pat The Bunny': ['acoustic punk', 'folk punk'],
#  'Brandon Chase': ['acoustic chill'],
#  'Get Dead': ['acoustic punk', 'folk punk', 'orgcore', 'skate punk'],
#  'Bailey Pelkman': ['acoustic chill'],
#  'Billy-Joe': ['instrumental acoustic guitar'],
#  'Aron Wright': ['acoustic pop', 'deep acoustic pop'],
#  'Junior Kimbrough': ['acoustic blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'Jae Hall': ['acoustic cover'],
#  'Grace George': ['acoustic cover'],
#  'Big Mama Thornton': ['acoustic blues',
#   'blues',
#   'harmonica blues',
#   'rhythm and blues',
#   'texas blues',
#   'traditional blues'],
#  'Caleb Santos': ['acoustic opm', 'opm'],
#  'Beyond The Guitar': ['instrumental acoustic guitar'],
#  'Eddy Tyler': ['acoustic guitar cover'],
#  'Mathew Joseph': ['instrumental acoustic guitar'],
#  'Rosie Thomas': ['acoustic pop', 'deep acoustic pop', 'ectofolk'],
#  'Wayne Mack': ['acoustic chill'],
#  'Tyler Hilton': ['acoustic pop', 'neo mellow', 'oth indie'],
#  'J.B. Lenoir': ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'traditional blues'],
#  'Katie Herzig': ['acoustic pop'],
#  'Ysabelle Cuevas': ['acoustic opm'],
#  'Graham Colton': ['acoustic pop', 'folk-pop', 'okc indie'],
#  'Mississippi John Hurt': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'piedmont blues',
#   'traditional blues'],
#  'Daphne Willis': ['acoustic pop', 'bossbeat'],
#  'Filip Nordin': ['acoustic cover'],
#  'Kris Allen': ['acoustic pop', 'idol', 'neo mellow', 'viral pop'],
#  'Jürg Kindle': ['instrumental acoustic guitar'],
#  'Tony Sly': ['acoustic rock', 'skate punk'],
#  'Lucy Schwartz': ['acoustic pop', 'deep acoustic pop'],
#  'Zak Manley': ['acoustic chill'],
#  'Ken Verheecke': ['instrumental acoustic guitar'],
#  'Eddie van der Meer': ['acoustic guitar cover', 'otacore'],
#  'Kevin Simm': ['acoustic cover', 'lancashire indie'],
#  'Isabella Celander': ['acoustic cover'],
#  'Matt White': ['acoustic pop', 'neo mellow'],
#  'Hannah Trigwell': ['acoustic cover', 'viral pop'],
#  'Isato Nakagawa': ['fingerstyle',
#   'instrumental acoustic guitar',
#   'japanese guitar'],
#  'Lunng Fern': ['instrumental acoustic guitar'],
#  'Cary Brothers': ['acoustic pop', 'la indie'],
#  'Paul Canning': ['acoustic cover'],
#  'Keith McInally': ['acoustic cover'],
#  'Blame Jones': ['acoustic cover'],
#  'Obadiah Parker': ['acoustic cover'],
#  'Roy Buchanan': ['acoustic blues',
#   'blues',
#   'blues rock',
#   'electric blues',
#   'modern blues',
#   'traditional blues'],
#  'Matt Wertz': ['acoustic pop', 'neo mellow'],
#  'Lead Belly': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'texas blues',
#   'traditional blues'],
#  'Collin Hill': ['acoustic guitar cover'],
#  'krissy & ericka': ['acoustic opm', 'p-pop'],
#  'Otis Taylor': ['acoustic blues', 'country blues'],
#  'Matthew Perryman Jones': ['acoustic pop'],
#  'Maria Taylor': ['alabama indie', 'deep acoustic pop'],
#  'Aoi Teshima': ['anime score', 'j-acoustic'],
#  'Mindy Smith': ['acoustic pop', 'ectofolk', 'lilith'],
#  'Butterfly Boucher': ['deep acoustic pop'],
#  'YUZU': ['j-acoustic', 'j-pop'],
#  'Glenn Roth': ['acoustic guitar cover'],
#  'Joey Cape': ['acoustic rock', 'skate punk'],
#  'Griffin House': ['acoustic pop'],
#  '40 Fingers': ['acoustic guitar cover'],
#  'Sykomori': ['acoustic guitar cover'],
#  'Roberto Dalla Vecchia': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Wingnut Dishwashers Union': ['acoustic punk', 'folk punk'],
#  'Maygen Lacey': ['acoustic cover'],
#  'Ramshackle Glory': ['acoustic punk', 'folk punk', 'tucson indie'],
#  'Shannon & Keast': ['acoustic chill', 'acoustic cover', 'jazz cover'],
#  'Mysha Didi': ['acoustic chill'],
#  'Randal L Meek': ['instrumental acoustic guitar'],
#  'Brendan James': ['acoustic pop'],
#  'Champion Jack Dupree': ['acoustic blues',
#   'barrelhouse piano',
#   'blues',
#   'louisiana blues',
#   'memphis blues',
#   'new orleans blues',
#   'piano blues',
#   'traditional blues'],
#  'Nora & Will': ['acoustic cover'],
#  'Kitri': ['j-acoustic'],
#  'Laura Jane Grace': ['acoustic punk', 'folk punk'],
#  'Erin McCarley': ['acoustic pop'],
#  'Thomas Law': ['acoustic cover'],
#  'Will Moore': ['instrumental acoustic guitar'],
#  'Simon Samaeng': ['acoustic chill'],
#  'Tristan Prettyman': ['acoustic pop', 'neo mellow'],
#  'Karizma Duo': ['acoustic cover'],
#  'Nathan Angelo': ['acoustic pop'],
#  'Celestial Conscience': ['acoustic guitar cover'],
#  'Arthur "Big Boy" Crudup': ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'delta blues',
#   'traditional blues'],
#  'Meiko': ['acoustic pop'],
#  'Kaki King': ['instrumental acoustic guitar'],
#  'Jem': ['deep acoustic pop', 'lilith'],
#  'Paolo Velera': ['acoustic chill'],
#  'Corey Gray': ['acoustic cover', 'channel pop', 'viral pop'],
#  'Anna Hamilton': ['acoustic chill'],
#  'Eastmountainsouth': ['acoustic pop'],
#  'Rory Block': ['acoustic blues', 'country blues', 'modern blues'],
#  'Meg Birch': ['acoustic cover', 'jazz cover'],
#  'Live Lounge Allstars': ['acoustic cover'],
#  'Per-Olov Kindgren': ['instrumental acoustic guitar'],
#  'Apes of the State': ['acoustic punk',
#   'folk punk',
#   'lancaster pa indie',
#   'pittsburgh indie'],
#  'Lowell Fulson': ['acoustic blues',
#   'blues',
#   'electric blues',
#   'jump blues',
#   'soul blues',
#   'texas blues',
#   'traditional blues'],
#  'Anya Marina': ['ann arbor indie', 'deep acoustic pop'],
#  'Chris Cresswell': ['acoustic punk', 'acoustic rock', 'orgcore'],
#  'Green River Ordinance': ['acoustic pop', 'fort worth indie', 'neo mellow'],
#  'Linn Brikell': ['acoustic cover'],
#  'Josh Kelley': ['acoustic pop', 'neo mellow'],
#  'David Ramirez': ['acoustic pop',
#   'austin americana',
#   'indie folk',
#   'new americana'],
#  'Ronnie Earl': ['acoustic blues',
#   'blues',
#   'british blues',
#   'electric blues',
#   'modern blues'],
#  'Spritely': ['acoustic chill'],
#  'Amy Stroup': ['acoustic pop'],
#  'Human Petting Zoo': ['acoustic punk', 'ohio indie'],
#  'Mike Massé': ['acoustic cover'],
#  'Carly Lyman': ['acoustic cover'],
#  'Michelle Qureshi': ['instrumental acoustic guitar'],
#  'Trent Dabbs': ['acoustic pop', 'christian indie'],
#  'The Brilliance': ['acoustic pop',
#   'ambient worship',
#   'christian uplift',
#   'deep ccm',
#   'roots worship'],
#  'Caj Morgan': ['acoustic cover'],
#  'Emilio Bonito': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Blended Colours': ['acoustic chill'],
#  'Joe Louis Walker': ['acoustic blues',
#   'blues',
#   'british blues',
#   'electric blues',
#   'modern blues'],
#  'Ghost Mice': ['acoustic punk', 'folk punk'],
#  'Luca Stricagnoli': ['acoustic guitar cover', 'fingerstyle'],
#  'Just Nick': ['acoustic punk', 'folk punk'],
#  'NORMANDY': ['acoustic cover'],
#  'Son House': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'Snooks Eaglin': ['acoustic blues',
#   'blues',
#   'louisiana blues',
#   'new orleans blues',
#   'traditional blues'],
#  'Sue Foley': ['acoustic blues', 'canadian blues', 'modern blues'],
#  'Roberto Diana': ['instrumental acoustic guitar'],
#  'Jemma Johnson': ['acoustic chill'],
#  'Mississippi Fred McDowell': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues',
#   'traditional southern folk'],
#  'Future Of Forestry': ['acoustic pop', 'christian uplift', 'indiecoustica'],
#  'Andy Salvanos': ['chapman stick', 'instrumental acoustic guitar'],
#  'Mike Howe': ['instrumental acoustic guitar'],
#  'Rick Cyge': ['acoustic guitar cover'],
#  'Sonya': ['acoustic chill'],
#  'Will Hoge': ['acoustic pop', 'heartland rock'],
#  'Todd Carey': ['acoustic pop'],
#  'Highland Peak': ['acoustic chill'],
#  'Rosi Golan': ['acoustic pop'],
#  'Alexa Goddard': ['acoustic chill'],
#  'Jürgen Saalmann': ['instrumental acoustic guitar'],
#  'Jota John': ['acoustic cover'],
#  'Matthew Mayfield': ['acoustic pop'],
#  'Gabe Dixon': ['acoustic pop', 'piano rock'],
#  'Vin Downes': ['instrumental acoustic guitar'],
#  'Jamie Dupuis': ['instrumental acoustic guitar'],
#  'Matt Pless': ['acoustic punk', 'folk punk'],
#  'Olga Chung': ['acoustic chill', 'coverchill'],
#  'AcousticTrench': ['acoustic guitar cover'],
#  'Maris Racal': ['acoustic opm', 'opm', 'p-pop'],
#  'Blind Willie Johnson': ['acoustic blues',
#   'blues',
#   'country blues',
#   'gospel blues',
#   'texas blues',
#   'traditional blues'],
#  'J-Que Beenz': ['acoustic chill'],
#  'Mark Grundhoefer': ['instrumental acoustic guitar'],
#  'Sonny Terry': ['acoustic blues',
#   'blues',
#   'country blues',
#   'harmonica blues',
#   'piedmont blues',
#   'traditional blues'],
#  'Joey Edwin': ['acoustic guitar cover'],
#  'Richard Watts': ['acoustic cover'],
#  'Chris Embers': ['instrumental acoustic guitar'],
#  'Sébastien Hogge': ['acoustic guitar cover'],
#  'Skip James': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'Jeremy Lister': ['acoustic pop'],
#  'Yoshihiro Koseki': ['anime score',
#   'j-acoustic',
#   'japanese guitar',
#   'japanese instrumental'],
#  'Jay Filson': ['acoustic cover'],
#  'Matt Skiba': ['acoustic punk', 'chicago punk'],
#  'Ankle Grease': ['acoustic punk', 'folk punk'],
#  'Brownie McGhee': ['acoustic blues',
#   'blues',
#   'country blues',
#   'piedmont blues',
#   'traditional blues'],
#  'David Ryan Harris': ['acoustic pop'],
#  'Trevor Gordon Hall': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Magic Slim': ['acoustic blues', 'blues', 'electric blues'],
#  'Blind Willie McTell': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'piedmont blues',
#   'traditional blues'],
#  'Corporate Hearts': ['acoustic punk', 'folk punk'],
#  'Holy Locust': ['acoustic punk', 'folk punk'],
#  'The Rescues': ['deep acoustic pop'],
#  'Greg Steinfeld': ['acoustic cover'],
#  'Five Times August': ['acoustic pop'],
#  'Big Bill Broonzy': ['acoustic blues',
#   'blues',
#   'chicago blues',
#   'country blues',
#   'traditional blues'],
#  'Tres Hermanas': ['acoustic opm'],
#  'VENDEE': ['acoustic cover'],
#  'Tim Barry': ['acoustic punk', 'folk punk', 'orgcore'],
#  'Blackbird Raum': ['acoustic punk', 'folk punk', 'gypsy punk'],
#  'Humbert Humbert': ['j-acoustic'],
#  'Peter Gergely': ['acoustic guitar cover'],
#  'Carbe and Durand': ['acoustic guitar cover'],
#  'Suy Galvez': ['acoustic opm'],
#  'Thom Cooper': ['acoustic cover'],
#  'Tobey Rosen': ['acoustic chill'],
#  'Masayoshi Yamazaki': ['j-acoustic',
#   'j-pop',
#   'japanese blues',
#   'japanese singer-songwriter'],
#  'We The Heathens': ['acoustic punk', 'folk punk'],
#  'Steve Pulvers': ['acoustic guitar cover'],
#  'Alexandr Misko': ['acoustic guitar cover'],
#  'Victor Howe': ['instrumental acoustic guitar'],
#  'Gail Blanco': ['acoustic opm'],
#  'Rumbleseat': ['acoustic punk', 'folk punk', 'orgcore'],
#  'She/Her/hers': ['acoustic punk', 'queercore'],
#  'NTMY': ['acoustic chill'],
#  'Postcards & Polaroids': ['acoustic chill'],
#  'Roostz': ['acoustic cover'],
#  'Doug MacLeod': ['acoustic blues', 'blues'],
#  'Ben Botfield': ['acoustic chill'],
#  'Beans on Toast': ['acoustic punk'],
#  'El McMeen': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Summer Haze': ['acoustic chill'],
#  'Ohashi Trio': ['j-acoustic'],
#  'Hailey Gardiner': ['acoustic cover'],
#  'Joanie Loves Chachi': ['acoustic cover'],
#  'Bukka White': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'Sanders Bohlke': ['deep acoustic pop', 'mississippi indie'],
#  'Rev. Gary Davis': ['acoustic blues',
#   'country blues',
#   'gospel blues',
#   'piedmont blues',
#   'traditional blues'],
#  'I Am Kloot': ['acoustic rock'],
#  'Colder Shoulders': ['acoustic chill'],
#  'Gabriella Quevedo': ['acoustic guitar cover'],
#  'Kate York': ['acoustic pop'],
#  'Brimsley': ['acoustic chill'],
#  'Bandits Of The Acoustic Revolution': ['acoustic punk',
#   'folk punk',
#   'ska',
#   'ska punk'],
#  'Not Half Bad': ['acoustic punk', 'folk punk'],
#  'Water and Salt': ['acoustic chill'],
#  'Sunset & Highland': ['acoustic chill'],
#  'The Cameron Collective': ['acoustic chill'],
#  'Laurence O’Brien': ['acoustic cover'],
#  'Duke Robillard': ['acoustic blues',
#   'blues',
#   'british blues',
#   'electric blues',
#   'jazz blues',
#   'modern blues'],
#  'Guitar Slim': ['acoustic blues',
#   'blues',
#   'louisiana blues',
#   'new orleans blues',
#   'traditional blues'],
#  'Sonny Terry and Brownie McGhee': ['acoustic blues',
#   'blues',
#   'traditional blues'],
#  'Pete Huttlinger': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Keiichi Sokabe': ['j-acoustic', 'j-rock'],
#  'The Lidls': ['acoustic chill'],
#  'Dylan Ryche': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Shikao Suga': ['j-acoustic', 'japanese singer-songwriter'],
#  'Kate Havnevik': ['deep acoustic pop', 'etherpop'],
#  'Mateo Brooks': ['acoustic cover'],
#  'Keaton Simons': ['acoustic pop'],
#  'Lil Ed & The Blues Imperials': ['acoustic blues',
#   'blues',
#   'electric blues',
#   'modern blues'],
#  'Paper Ceilings': ['acoustic punk', 'folk punk'],
#  'Thomas Conti': ['acoustic cover'],
#  'Tony Lucca': ['acoustic pop'],
#  'Raphiel Shannon': ['acoustic opm'],
#  'Eiro Nareth': ['acoustic guitar cover'],
#  'Jeff Wahl': ['christmas instrumental', 'instrumental acoustic guitar'],
#  'Retreat': ['acoustic cover'],
#  'Mark Kroos': ['instrumental acoustic guitar'],
#  'Guy Davis': ['acoustic blues', 'country blues', 'piedmont blues'],
#  'Inara George': ['deep acoustic pop', 'folk-pop'],
#  'Nik Davies': ['instrumental acoustic guitar'],
#  'Mone Kamishiraishi': ['j-acoustic', 'j-pop'],
#  'Matt Hires': ['acoustic pop', 'tampa indie'],
#  'Aleko Nunez': ['acoustic guitar cover'],
#  'Corey Harris': ['acoustic blues', 'country blues', 'modern blues'],
#  'The String Revolution': ['classify', 'instrumental acoustic guitar'],
#  'Rail Yard Ghosts': ['acoustic punk',
#   'deathgrass',
#   'folk punk',
#   'gypsy punk'],
#  'Jimmy Wahlsteen': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Justin Morgan': ['acoustic chill'],
#  'A.B. Chediski': ['instrumental acoustic guitar'],
#  'Masaharu Fukuyama': ['classic j-pop',
#   'j-acoustic',
#   'j-pop',
#   'japanese singer-songwriter'],
#  'Mike Herrera': ['acoustic punk'],
#  'Big Joe Williams': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'traditional blues'],
#  'SYLVAN': ['acoustic cover'],
#  'John Standefer': ['classify', 'instrumental acoustic guitar'],
#  'Human Kitten': ['acoustic punk', 'folk punk'],
#  'Charley Patton': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'pre-war blues',
#   'traditional blues'],
#  'Aidan Hawken': ['acoustic pop'],
#  'Bobbylene': ['acoustic cover'],
#  'Luluc': ['deep acoustic pop'],
#  'Memphis Minnie': ['acoustic blues',
#   'blues',
#   'country blues',
#   'memphis blues',
#   'traditional blues'],
#  'Muriel Anderson': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Toby Lightman': ['acoustic pop'],
#  'Tim Thompson': ['acoustic guitar cover'],
#  'Iko': ['deep acoustic pop', 'minimal wave'],
#  'Pinetop Perkins': ['acoustic blues',
#   'blues',
#   'boogie-woogie',
#   'delta blues',
#   'piano blues',
#   'traditional blues'],
#  'Le Vitates': ['acoustic chill'],
#  'Jon Snodgrass': ['acoustic rock'],
#  'Ernie Halter': ['acoustic pop', 'neo mellow'],
#  'Ali Harter': ['deep acoustic pop', 'ok indie'],
#  'Yu Takahashi': ['j-acoustic', 'j-pop', 'japanese singer-songwriter'],
#  'The Shaken Bakers': ['acoustic cover'],
#  'James Bartholomew': ['acoustic guitar cover'],
#  'Heike Matthiesen': ['instrumental acoustic guitar'],
#  'Billy Watman': ['acoustic guitar cover'],
#  'Matt Harp': ['acoustic guitar cover'],
#  'Marie Knight': ['acoustic blues'],
#  'Dan Andriano in the Emergency Room': ['acoustic rock', 'folk punk'],
#  'Schuyler Fisk': ['acoustic pop', 'lilith'],
#  'RENT STRIKE': ['acoustic punk', 'folk punk'],
#  'Jon Hart': ['acoustic guitar cover'],
#  'Tamio Okuda': ['j-acoustic',
#   'j-pop',
#   'j-rock',
#   'japanese singer-songwriter'],
#  'SANNA NORTH': ['acoustic cover'],
#  'Emilie Mover': ['deep acoustic pop'],
#  'Naotaro Moriyama': ['j-acoustic', 'j-pop', 'japanese singer-songwriter'],
#  'Jenny & Tyler': ['acoustic pop', 'christian indie', 'roots worship'],
#  'Chad Hates George': ['acoustic punk', 'folk punk'],
#  'Yosui Inoue': ['j-acoustic', 'japanese singer-songwriter', 'kayokyoku'],
#  'Sara Jackson-Holman': ['deep acoustic pop'],
#  'Donovan Raitt': ['fingerstyle', 'instrumental acoustic guitar'],
#  'The Freed': ['acoustic chill'],
#  'Brooke Waggoner': ['acoustic pop'],
#  'Lonnie Johnson': ['acoustic blues',
#   'blues',
#   'country blues',
#   'jazz blues',
#   'louisiana blues',
#   'memphis blues',
#   'new orleans blues',
#   'traditional blues'],
#  'Trashbag Ponchos': ['acoustic punk', 'folk punk', 'lincoln ne indie'],
#  'Tim Vantol': ['acoustic punk', 'dutch americana'],
#  'Mattias Krantz': ['acoustic guitar cover'],
#  'Vivid Color': ['acoustic chill'],
#  '上野大樹': ['j-acoustic'],
#  'Jesus Jackson': ['deep acoustic pop'],
#  'Daria Semikina': ['instrumental acoustic guitar', 'japanese guitar'],
#  'Larry Pattis': ['fingerstyle', 'instrumental acoustic guitar'],
#  'Calvi': ['acoustic chill'],
#  'Vinyl Hotel': ['acoustic cover'],
#  "Yesterday's Ring": ['acoustic punk', 'quebec punk'],
#  'Tampa Red': ['acoustic blues',
#   'chicago blues',
#   'country blues',
#   'traditional blues'],
#  'Raye Mills': ['acoustic chill'],
#  'Cloudsmiff': ['acoustic cover'],
#  'K.S. Rhoads': ['acoustic pop', 'stomp and holler'],
#  'Alberto Lombardi': ['instrumental acoustic guitar'],
#  'Powell Sullivan': ['acoustic chill'],
#  'Elenowen': ['acoustic pop'],
#  'Treadlights': ['acoustic chill'],
#  'Humming House': ['acoustic pop'],
#  'Seba Gaido & Martin Roman': ['acoustic cover'],
#  'Dean Dyson': ['acoustic cover'],
#  'Onsind': ['acoustic punk', 'folk punk', 'queercore'],
#  'Richie Aikman': ['acoustic guitar cover'],
#  'Get Set Go': ['deep acoustic pop'],
#  'Alvin Youngblood Hart': ['acoustic blues', 'country blues', 'modern blues'],
#  'Emerson Hart': ['acoustic pop', 'neo mellow'],
#  'Sakurako Ohara': ['j-acoustic', 'j-pop'],
#  "Fink's Mood": ['acoustic chill'],
#  'Correatown': ['deep acoustic pop'],
#  'Neulore': ['acoustic pop', 'folk-pop'],
#  'Louisiana Red': ['acoustic blues',
#   'blues',
#   'louisiana blues',
#   'traditional blues'],
#  'Van Larkins': ['acoustic guitar cover', 'fingerstyle'],
#  'Plain Simple': ['acoustic chill'],
#  'Henry Thomas': ['acoustic blues',
#   'appalachian folk',
#   'jug band',
#   'traditional blues',
#   'traditional folk'],
#  'Marco Pisani': ['instrumental acoustic guitar'],
#  'Hanare Gumi': ['j-acoustic', 'j-rock'],
#  'Kurt Lanham': ['acoustic guitar cover'],
#  'Blind Lemon Jefferson': ['acoustic blues',
#   'blues',
#   'country blues',
#   'delta blues',
#   'gospel blues',
#   'pre-war blues',
#   'texas blues',
#   'traditional blues'],
#  'Jared Hart': ['acoustic punk'],
#  'Madamarye': ['acoustic cover'],
#  'Lucas Silver': ['acoustic guitar cover'],
#  'Sakura Fujiwara': ['j-acoustic', 'japanese singer-songwriter'],
#  'Ann Sally': ['j-acoustic', 'japanese vocal jazz'],
#  'Ben Weighill': ['acoustic cover'],
#  'The Donnies The Amys': ['deep acoustic pop'],
#  'Eden Brent': ['acoustic blues', 'piano blues'],
#  'Dale Sutton': ['acoustic cover'],
#  'Tim Schou': ['acoustic chill'],
#  'Stephen Kellogg': ['acoustic pop'],
#  'Audio/Rocketry': ['acoustic punk', 'edmonton indie'],
#  'Akiko Yano': ['j-acoustic', 'japanese singer-songwriter', 'techno kayo'],
#  'Robbie Wadge': ['acoustic chill'],
#  'Angelina Cruz': ['acoustic opm', 'opm'],
#  'Lurrie Bell': ['acoustic blues',
#   'blues',
#   'blues-rock guitar',
#   'electric blues',
#   'modern blues',
#   'power blues-rock'],
#  'Scorpios': ['acoustic punk', 'acoustic rock'],
#  'Bob Margolin': ['acoustic blues',
#   'blues',
#   'electric blues',
#   'modern blues',
#   'power blues-rock'],
#  'Jules Larson': ['acoustic pop', 'bossbeat', 'deep indie singer-songwriter'],
#  'Eddie Taylor': ['acoustic blues',
#   'blues',
#   'electric blues',
#   'traditional blues'],
#  'Predawn': ['j-acoustic', 'japanese indie folk'],
#  'Kevin Seconds': ['acoustic punk', 'sacramento indie'],
#  'Unkle Bob': ['deep acoustic pop'],
#  'Jay Nash': ['acoustic pop'],
#  'Shelby Park': ['acoustic chill'],
#  'Matt Duke': ['acoustic pop'],
#  'Ethan Loukas': ['acoustic opm'],
#  'Sim Tillis': ['acoustic chill'],
#  'Rema': ['afrobeats', 'nigerian pop'],
#  'Burna Boy': ['afrobeats', 'dancehall', 'nigerian hip hop', 'nigerian pop'],
#  'Wizkid': ['afrobeats',
#   'afropop',
#   'azonto',
#   'azontobeats',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Ayra Starr': ['afrobeats'],
#  'Tems': ['afro r&b', 'afrobeats', 'alte', 'nigerian pop'],
#  'Davido': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'ghanaian hip hop',
#   'nigerian pop'],
#  'Libianca': ['afrobeats'],
#  'Fireboy DML': ['afrobeats', 'nigerian pop'],
#  'Omah Lay': ['afrobeats', 'nigerian pop'],
#  'Asake': ['afrobeats', 'nigerian pop'],
#  'CKay': ['afro r&b', 'afrobeats'],
#  'BNXN fka Buju': ['afrobeats', 'nigerian pop'],
#  'Oxlade': ['afrobeats', 'nigerian pop'],
#  'Kizz Daniel': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Victony': ['afrobeats', 'nigerian pop'],
#  'Ruger': ['afrobeats', 'nigerian pop'],
#  'Tempoe': ['afrobeats'],
#  'Pheelz': ['afrobeats', 'nigerian pop'],
#  'Lojay': ['afrobeats', 'alte', 'nigerian pop'],
#  'melvitto': ['afrobeats', 'nigerian pop'],
#  'Adekunle Gold': ['afrobeats',
#   'afropop',
#   'alte',
#   'azontobeats',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Joeboy': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Tiwa Savage': ['afrobeats', 'afropop', 'azonto', 'nigerian pop'],
#  'Amaarae': ['afro r&b',
#   'afrobeats',
#   'alternative r&b',
#   'ghanaian alternative',
#   'ghanaian pop'],
#  'Olamide': ['afrobeats',
#   'afropop',
#   'azonto',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Mr Eazi': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'ghanaian hip hop',
#   'nigerian pop',
#   'swedish dancehall'],
#  'Sarz': ['afrobeats', 'nigerian pop'],
#  'Young Jonn': ['afrobeats', 'nigerian pop'],
#  '1da Banton': ['afrobeats', 'nigerian pop'],
#  'Magixx': ['afrobeats', 'nigerian pop'],
#  'Zinoleesky': ['afrobeats', 'nigerian pop'],
#  'JayO': ['afrobeats'],
#  'Darkoo': ['afrobeats', 'afroswing', 'london rap', 'uk hip hop'],
#  'Bayanni': ['afrobeats', 'nigerian pop'],
#  'Fuse ODG': ['afrobeats', 'azonto'],
#  'Gabzy': ['afrobeats', 'nigerian pop'],
#  'Black Sherif': ['afrobeats', 'ghanaian pop'],
#  'L.A.X': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Fave': ['afrobeats', 'alte', 'nigerian pop'],
#  'Crayon': ['indie soul', 'new french touch'],
#  'SPINALL': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Tekno': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Wande Coal': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Mayorkun': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'LADIPOE': ['afrobeats', 'nigerian pop'],
#  'King Promise': ['afrobeats', 'ghanaian alternative', 'ghanaian pop'],
#  'Boy Spyce': ['afrobeats', 'nigerian pop'],
#  'KiDi': ['afrobeats', 'ghanaian pop'],
#  'Nonso Amadi': ['afrobeats', 'alte', 'nigerian pop'],
#  'EMPIRE': ['afrobeats'],
#  'Mavins': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'El Michels Affair': ['afrobeat', 'funk', 'instrumental soul'],
#  'DJ Tunez': ['afrobeats', 'nigerian pop'],
#  'Afro B': ['afrobeats',
#   'afroswing',
#   'dancehall',
#   'uk dancehall',
#   'uk hip hop'],
#  'Limoblaze': ['christian afrobeat'],
#  'Timaya': ['afrobeats', 'afropop', 'azonto', 'dancehall', 'nigerian pop'],
#  'Maleek Berry': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'nigerian pop',
#   'swedish dancehall',
#   'uk dancehall'],
#  'Naira Marley': ['afrobeats', 'afroswing', 'nigerian pop'],
#  'Skiibii': ['afrobeats', 'nigerian pop'],
#  'Camidoh': ['afro r&b', 'afrobeats', 'ghanaian pop'],
#  'Seyi Vibez': ['afrobeats', 'nigerian pop'],
#  'Patoranking': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'NSG': ['afrobeats', 'afroswing', 'uk dancehall', 'uk hip hop'],
#  'Babyboy AV': ['afrobeats'],
#  'Ayo Jay': ['afrobeats'],
#  'Boj': ['afrobeats', 'alte', 'nigerian pop'],
#  'StarBoy': ['afrobeats'],
#  'Korede Bello': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Juls': ['afrobeats', 'afroswing', 'uk dancehall'],
#  'Runtown': ['afrobeats', 'afropop', 'nigerian pop'],
#  'The Cavemen.': ['afrobeats', 'alte', 'nigerian pop'],
#  'Yemi Alade': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'The Budos Band': ['afrobeat',
#   'ethio-jazz',
#   'instrumental funk',
#   'instrumental soul'],
#  'Zlatan': ['afrobeats', 'nigerian pop'],
#  'Flavour': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'igbo pop',
#   'nigerian pop'],
#  'P-Square': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'bongo flava',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'CalledOut Music': ['christian afrobeat'],
#  'Bella Shmurda': ['afrobeats', 'nigerian pop'],
#  'Stonebwoy': ['afrobeats', 'dancehall', 'ghanaian pop', 'hiplife'],
#  'Kuami Eugene': ['afrobeats', 'asakaa', 'azonto'],
#  'Johnny Drille': ['afrobeats', 'nigerian pop'],
#  'Darondo': ['afrobeat', 'funk', 'traditional soul'],
#  'Simi': ['afrobeats', 'afropop', 'alte', 'azontobeats', 'nigerian pop'],
#  'Iyanya': ['afrobeats', 'afropop', 'nigerian pop'],
#  'JAE5': ['afrobeats'],
#  'Gyakie': ['afro r&b', 'afrobeats', 'nigerian pop'],
#  'Minz': ['afrobeats', 'nigerian pop'],
#  'Chike': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Shatta Wale': ['afrobeats', 'ghanaian pop'],
#  'Rexxie': ['afrobeats', 'nigerian pop'],
#  'Majeeed': ['afrobeats', 'nigerian pop'],
#  'Mulatu Astatke': ['afrobeat', 'afropop', 'ethio-jazz', 'world'],
#  'Blaqbonez': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Peruzzi': ['afrobeats', 'dancehall', 'nigerian pop'],
#  'ODUMODUBLVCK': ['afro drill', 'afrobeats', 'nigerian pop'],
#  'Ice Prince': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Calle 13': ['latin afrobeat',
#   'latin alternative',
#   'latin hip hop',
#   'puerto rican rock',
#   'rap conciencia',
#   'reggaeton',
#   'rock en espanol'],
#  'Odeal': ['afrobeats', 'uk contemporary r&b'],
#  'Bad Boy Timz': ['afrobeats', 'nigerian pop'],
#  'Terri': ['afrobeats', 'nigerian pop'],
#  'MoStack': ['afrobeats', 'afroswing', 'grime', 'london rap', 'uk hip hop'],
#  'Gil Scott-Heron': ['afrobeat',
#   'afropop',
#   'conscious hip hop',
#   'funk',
#   'jazz funk',
#   'political hip hop',
#   'slam poetry',
#   'soul'],
#  'Sarkodie': ['afrobeats',
#   'afropop',
#   'azonto',
#   'azontobeats',
#   'ghanaian hip hop'],
#  'Teni': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Reekado Banks': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Khaid': ['afrobeats', 'nigerian pop'],
#  'Lee Fields & The Expressions': ['afrobeat', 'funk', 'soul'],
#  'Ceeza Milli': ['afrobeats', 'nigerian pop'],
#  'Ajebo Hustlers': ['afrobeats', 'nigerian pop'],
#  'DJ Neptune': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Cheque': ['afrobeats', 'nigerian pop'],
#  'King Perryy': ['afrobeats', 'nigerian pop'],
#  'Show Dem Camp': ['afrobeats', 'alte', 'nigerian hip hop', 'nigerian pop'],
#  'Falz': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Marizu': ['christian afrobeat', 'rap chretien'],
#  'Fela Kuti': ['afrobeat', 'afropop', 'world'],
#  'Odunsi (The Engine)': ['afrobeats', 'alte', 'nigerian pop'],
#  'Eugy': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'ghanaian hip hop',
#   'swedish dancehall',
#   'uk dancehall'],
#  'Moelogo': ['afrobeats', 'nigerian pop'],
#  'DJ Big N': ['afrobeats', 'nigerian pop'],
#  'Kid AlpHa': ['afrobeats'],
#  'Niniola': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Ycee': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Kida Kudz': ['afrobeats', 'nigerian pop'],
#  'Ajebutter22': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Phyno': ['afrobeats',
#   'afropop',
#   'igbo pop',
#   'igbo rap',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Jorge Drexler': ['cantautor',
#   'latin afrobeat',
#   'latin alternative',
#   'latin rock',
#   'nueva cancion',
#   'trova'],
#  'Seun Kuti': ['afrobeat', 'afropop'],
#  'Praiz': ['afro r&b', 'afrobeats', 'nigerian pop'],
#  'Cymande': ['afrobeat', 'funk', 'jazz funk', 'psychedelic soul'],
#  'Prinx Emmanuel': ['christian afrobeat'],
#  'Ikebe Shakedown': ['instrumental funk', 'latin afrobeat'],
#  'Mohbad': ['afrobeats', 'nigerian pop'],
#  'Kwesi Arthur': ['afrobeats', 'ghanaian hip hop', 'ghanaian pop'],
#  '2Baba': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Prettyboy D-O': ['afrobeats', 'alte', 'nigerian pop'],
#  "D'banj": ['afrobeats', 'afropop', 'nigerian pop'],
#  'Egypt 80': ['afrobeat'],
#  'WurlD': ['afrobeats', 'alte', 'nigerian pop'],
#  'Skales': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Manu Dibango': ['afrobeat', 'afropop', 'makossa', 'world'],
#  'Rehmahz': ['christian afrobeat'],
#  'Yung L': ['afrobeats', 'nigerian pop'],
#  'Festizie': ['christian afrobeat'],
#  'Poco Lee': ['afrobeats', 'cruise', 'nigerian pop'],
#  'Lil Kesh': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Bisa Kdei': ['afrobeats', 'ghanaian hip hop', 'ghanaian pop'],
#  'DRB Lasgidi': ['afrobeats', 'alte', 'nigerian pop'],
#  'R2Bees': ['afrobeats', 'ghanaian hip hop', 'ghanaian pop'],
#  'PsychoYP': ['afrobeats', 'nigerian pop'],
#  'Ebo Taylor': ['afro-funk', 'afrobeat', 'afropop', 'old school highlife'],
#  'Los Amigos Invisibles': ['latin afrobeat',
#   'latin alternative',
#   'latin funk',
#   'rock en espanol',
#   'venezuelan indie',
#   'venezuelan rock'],
#  'Hotkid': ['afrobeats', 'nigerian pop'],
#  'T.I BLAZE': ['afrobeats', 'nigerian pop'],
#  'The Poets Of Rhythm': ['afrobeat', 'bboy'],
#  'J. Martins': ['afrobeats', 'afropop', 'nigerian pop'],
#  'M.I. Abaga': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Tony Allen': ['afrobeat', 'afropop', 'world'],
#  'William Onyeabor': ['afrobeat', 'afropop'],
#  'Vector': ['afrobeats', 'nigerian pop'],
#  'Nkay': ['christian afrobeat'],
#  'Orgone': ['afrobeat', 'brass band', 'instrumental funk', 'modern funk'],
#  'King Sunny Ade': ['afrobeat', 'afropop', 'griot', 'juju'],
#  'Lijadu Sisters': ['afrobeat', 'afropop', 'world'],
#  'Larry Gaaga': ['afrobeats', 'afropop', 'igbo pop', 'nigerian pop'],
#  'The Bongo Hop': ['afrobeat fusion'],
#  'The Souljazz Orchestra': ['afrobeat',
#   'bboy',
#   'brass band',
#   'instrumental funk',
#   'latin afrobeat'],
#  'Banky W.': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Reminisce': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'He3b': ['afrobeats'],
#  'Kofi Dartey': ['christian afrobeat'],
#  'Greatman Takit': ['christian afrobeat'],
#  'Voilaaa': ['afrobeat'],
#  'Ondatrópica': ['chicha',
#   'folclor afrocolombiano',
#   'latin afrobeat',
#   'nu-cumbia'],
#  'DarkoVibes': ['afrobeats', 'ghanaian alternative', 'ghanaian hip hop'],
#  'Duncan Mighty': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Gil Joe': ['christian afrobeat', 'rap chretien'],
#  'Sean Tizzle': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Brymo': ['afrobeats', 'afropop', 'alte', 'nigerian hip hop', 'nigerian pop'],
#  'Eben': ['christian afrobeat', 'naija worship'],
#  'HarrySong': ['afrobeats', 'afropop', 'nigerian pop'],
#  'TBabz': ['christian afrobeat'],
#  'Seyi Shay': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Efya': ['afrobeats', 'azonto', 'ghanaian alternative', 'hiplife'],
#  'Portable': ['afrobeats', 'cruise', 'nigerian pop'],
#  'Awilo Longomba': ['afrobeats',
#   'afropop',
#   'azontobeats',
#   'ndombolo',
#   'nigerian hip hop',
#   'soukous'],
#  'Basketmouth': ['afrobeats', 'igbo pop', 'nigerian pop'],
#  'Emandiong': ['christian afrobeat'],
#  'KCee': ['afrobeats', 'afropop', 'igbo pop', 'nigerian pop'],
#  'Criolo': ['afrobeat brasileiro',
#   'brazilian hip hop',
#   'brazilian reggae',
#   'latin afrobeat',
#   'manguebeat',
#   'mpb'],
#  'Dr SID': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'A Mose': ['christian afrobeat'],
#  "Jor'dan Armstrong": ['christian afrobeat', 'christian hip hop'],
#  'Nosa': ['christian afrobeat'],
#  'Lara George': ['christian afrobeat', 'naija worship'],
#  'Oba Reengy': ['christian afrobeat'],
#  'Antibalas': ['afrobeat', 'latin afrobeat', 'world'],
#  'The Heliocentrics': ['afrobeat', 'british jazz', 'psychedelic jazz fusion'],
#  'Wendy Shay': ['azonto',
#   'christian afrobeat',
#   'ghanaian alternative',
#   'hiplife'],
#  'Me and My Friends': ['afrobeat fusion'],
#  "D'Prince": ['afrobeats',
#   'afropop',
#   'igbo pop',
#   'naija old school',
#   'nigerian pop'],
#  'Carterefe': ['afrobeats', 'nigerian pop'],
#  'Duncan Daniels': ['afrobeats'],
#  'May D': ['afrobeats', 'afropop', 'nigerian pop'],
#  '9ice': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Masterkraft': ['afrobeats', 'afropop', 'nigerian pop'],
#  "Di'Ja": ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Styl-Plus': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Fiokee': ['afrobeats', 'nigerian pop'],
#  'Kiki Gyan': ['afrobeat', 'disco'],
#  'Elikem Kofi': ['christian afrobeat'],
#  'Sarah Téibo': ['christian afrobeat'],
#  'Orezi': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Cuppy': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Plastilina Mosh': ['electro latino',
#   'latin afrobeat',
#   'latin alternative',
#   'mexican rock',
#   'rock en espanol'],
#  'Dice Ailes': ['afrobeats', 'afropop', 'nigerian pop'],
#  'TB1': ['christian afrobeat'],
#  'Chidinma': ['afrobeats', 'afropop', 'azontobeats', 'nigerian hip hop'],
#  'Lyta': ['afrobeats', 'nigerian pop'],
#  'Omawumi': ['afrobeats', 'afropop', 'nigerian pop'],
#  'BaianaSystem': ['afrobeat brasileiro',
#   'brazilian indie',
#   'dub brasileiro',
#   'manguebeat',
#   'mpb',
#   'nova mpb',
#   'pop nacional',
#   'samba reggae'],
#  'The Funkees': ['afro psych', 'afro-funk', 'afrobeat', 'afropop'],
#  'Puppi': ['afrobeat brasileiro'],
#  'Amanda Malela': ['african gospel', 'christian afrobeat'],
#  'Oladapo': ['afrobeats', 'alte', 'nigerian pop'],
#  'Savage': ['italian disco', 'nz hip hop'],
#  'Nolly': ['christian afrobeat'],
#  'Victor AD': ['afrobeats', 'nigerian pop'],
#  'Pat Kalla': ['afrobeat fusion'],
#  'Chico Mann': ['latin afrobeat', 'latintronica'],
#  'Karl Hector & The Malcouns': ['afrobeat', 'psychedelic jazz fusion'],
#  'Timi Dakolo': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Barry Jhay': ['afrobeats', 'nigerian pop'],
#  'Becca Folkes': ['christian afrobeat'],
#  'Anendlessocean': ['christian afrobeat'],
#  'Lafayette Afro Rock Band': ['afrobeat', 'bboy', 'funk', 'jazz funk'],
#  'Angeloh': ['christian afrobeat'],
#  'Dj Horphuray': ['christian afrobeat'],
#  'Dotman': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Mut4y': ['afrobeats', 'nigerian pop'],
#  'Dremo': ['afrobeats', 'igbo trap', 'nigerian pop'],
#  'Buchi': ['christian afrobeat', 'naija worship'],
#  'Sharyn': ['christian afrobeat'],
#  'Jungle Fire': ['latin afrobeat', 'nu-cumbia'],
#  'DMW': ['afrobeats', 'nigerian pop'],
#  'Femi Kuti': ['afrobeat', 'afropop', 'world'],
#  'Password': ['christian afrobeat'],
#  'Kaptain': ['afrobeats', 'nigerian pop'],
#  'Ebony': ['afrobeats', 'azonto', 'hiplife'],
#  'Dele Sosimi': ['afrobeat'],
#  'Brownout': ['bboy', 'instrumental funk', 'latin afrobeat'],
#  'TJ Cream': ['christian afrobeat', 'gospel drill'],
#  'Selebobo': ['afrobeats', 'afropop', 'igbo pop', 'nigerian pop'],
#  'Ocote Soul Sounds': ['afrobeat', 'bboy', 'latin afrobeat'],
#  'Krizbeatz': ['afrobeats', 'gengetone', 'nigerian pop'],
#  'T. P. Orchestre Poly-Rythmo': ['afrobeat',
#   'afropop',
#   'beninese pop',
#   'classic afrobeat'],
#  'Kwamz & Flava': ['afrobeats', 'azonto', 'azontobeats'],
#  'Wizboyy': ['afrobeats', 'afropop', 'azontobeats', 'nigerian pop'],
#  'Yussef Kamaal': ['afrobeat',
#   'contemporary jazz',
#   'indie jazz',
#   'indie soul',
#   'uk contemporary jazz'],
#  'Falle Nioke': ['afrobeat fusion'],
#  'Francis Bebey': ['afrobeat', 'afropop', 'world'],
#  'Qdot': ['afrobeats', 'nigerian pop'],
#  'Bola Johnson': ['afrobeat', 'classic afrobeat', 'highlife'],
#  'Sir Victor Uwaifo': ['afrobeat', 'classic afrobeat', 'highlife', 'juju'],
#  'Funbi': ['alte', 'christian afrobeat', 'nigerian pop'],
#  'Afolake': ['christian afrobeat'],
#  'Nizzy': ['afrobeats'],
#  'Dai Verse': ['afrobeats'],
#  'Orlando Julius': ['afro-funk', 'afrobeat', 'afropop'],
#  'Gospel Hydration': ['christian afrobeat'],
#  'Jesse Jagz': ['afrobeats',
#   'afropop',
#   'azonto',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'The Mauskovic Dance Band': ['dutch indie rock', 'latin afrobeat'],
#  'Meridian Brothers': ['latin afrobeat', 'latintronica'],
#  'Protek Illasheva': ['christian afrobeat'],
#  'Gaise Baba': ['christian afrobeat'],
#  'MzVee': ['afrobeats', 'azonto', 'azontobeats', 'hiplife'],
#  'Les Mamans du Congo': ['afrobeat fusion'],
#  'Sugarboy': ['afrobeats', 'nigerian pop'],
#  'Nero X': ['azonto', 'christian afrobeat', 'hiplife'],
#  'Nathanael': ['christian afrobeat', 'gospel reggae'],
#  'Chinko Ekun': ['afrobeats', 'nigerian pop'],
#  'Erigga': ['afrobeats', 'nigerian pop'],
#  'Gyedu-Blay Ambolley': ['afrobeat', 'highlife'],
#  'Okey Sokay': ['christian afrobeat'],
#  'Ruff-N-Smooth': ['afrobeats', 'azonto', 'hiplife'],
#  'Eddie Neblett': ['christian afrobeat', 'gospel reggae'],
#  'Jaron Nurse': ['christian afrobeat', 'gospel reggae'],
#  'Malcolm Rue': ['christian afrobeat'],
#  'CDQ': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Vaudou Game': ['afrobeat', 'afropop', 'togolese pop'],
#  'Zoro': ['afrobeats', 'igbo pop', 'igbo rap', 'nigerian pop'],
#  'Dagrin': ['afrobeats', 'afropop', 'nigerian pop'],
#  "Jow'ell Bombay": ['african gospel', 'christian afrobeat', 'french worship'],
#  'Dangbana Republik': ['afrobeats', 'nigerian pop'],
#  'Joshua Ali': ['christian afrobeat', 'gospel reggae'],
#  "Ko'rale": ['christian afrobeat', 'gospel amapiano'],
#  'Solidstar': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Mandrill': ['classic soul',
#   'funk',
#   'jazz funk',
#   'latin afrobeat',
#   'p funk',
#   'soul jazz'],
#  'Joni Haastrup': ['afrobeat', 'classic afrobeat'],
#  'Mista Silva': ['afrobeats'],
#  'Oritse Femi': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Henrisoul': ['christian afrobeat'],
#  'T-Classic': ['afrobeats', 'nigerian pop'],
#  'Olu Maintain': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Samini': ['afrobeats', 'azonto', 'ghanaian pop', 'hiplife'],
#  'King Dareal': ['christian afrobeat'],
#  'Naeto C': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Magnito': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Jamopyper': ['afrobeats', 'cruise', 'nigerian pop'],
#  'Waje': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Osibisa': ['afrobeat', 'afropop'],
#  'Spillz Ochai': ['christian afrobeat'],
#  'Dos Santos': ['latin afrobeat'],
#  'Rae Rae': ['christian afrobeat'],
#  'Peter King': ['afrobeat'],
#  'Rex Williams': ['classic afrobeat'],
#  'The Hygrades': ['afro psych', 'classic afrobeat'],
#  'The Sugarman 3': ['afrobeat', 'bboy', 'hammond organ'],
#  'LAYCON': ['afrobeats', 'nigerian pop'],
#  'Gasmilla': ['afrobeats', 'ghanaian pop'],
#  'The Shaolin Afronauts': ['afrobeat', 'bboy', 'ethio-jazz'],
#  'Terry Apala': ['afrobeats', 'nigerian pop'],
#  'Marijata': ['afrobeat', 'classic afrobeat'],
#  'Small Doctor': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Sam Jamz': ['christian afrobeat'],
#  'J Prince': ['christian afrobeat', 'gospel reggae'],
#  'DJ Kaywise': ['afrobeats', 'afropop', 'cruise', 'nigerian pop'],
#  'MC Galaxy': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Sir Shina Peters': ['afrobeats', 'afropop', 'juju'],
#  'Sammie Ekpoh': ['christian afrobeat'],
#  'Dammy Krane': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Lola Rae': ['afrobeats'],
#  'HumbleSmith': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Shina Williams & His African Percussionists': ['african percussion',
#   'afrobeat'],
#  'Jaywon': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Lagbaja': ['afrobeat', 'afrobeats'],
#  'Juanafé': ['chilean rock', 'cumbia chilena', 'latin afrobeat'],
#  'El Rego': ['afro-funk', 'beninese pop', 'classic afrobeat'],
#  'Edem Evangelist': ['christian afrobeat'],
#  'Dj Consequence': ['afrobeats', 'nigerian pop'],
#  'Legendury Beatz': ['afrobeats', 'moombahton', 'nigerian pop'],
#  'Terry G': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Louis Pascal': ['christian afrobeat'],
#  '4x4': ['afrobeats', 'azonto', 'hiplife'],
#  'Sona': ['afrobeats'],
#  'BLO': ['afrobeat', 'classic afrobeat'],
#  'Urban Village': ['afrobeat fusion'],
#  "Mo' Hits All Stars": ['afrobeats', 'naija old school'],
#  'Sound Sultan': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Grupo Fantasma': ['latin afrobeat'],
#  'Abayomy Afrobeat Orquestra': ['afrobeat',
#   'afrobeat brasileiro',
#   'afrofuturismo brasileiro',
#   'brazilian indie',
#   'latin afrobeat',
#   'manguebeat'],
#  'Monomono': ['afro psych', 'classic afrobeat'],
#  'Niña Dioz': ['latin afrobeat',
#   'mexican hip hop',
#   'rap femenino mexicano',
#   'rap latina',
#   'trap mexicano'],
#  'Nomo': ['afrobeat'],
#  'Andrew Bello': ['christian afrobeat'],
#  'ST-Saint': ['christian afrobeat'],
#  'Lil Frosh': ['afrobeats', 'nigerian pop'],
#  'Bixiga 70': ['afrobeat brasileiro',
#   'afrofuturismo brasileiro',
#   'brass band brasileiro',
#   'brazilian indie',
#   'instrumental funk',
#   'latin afrobeat',
#   'nova mpb'],
#  'Qyubi': ['christian afrobeat'],
#  'AV': ['afrobeats', 'nigerian pop'],
#  'LeriQ': ['afrobeats', 'naija old school', 'nigerian pop'],
#  'Lilmizzy': ['christian afrobeat'],
#  'Alogte Oho & His Sounds of Joy': ['afrobeat fusion'],
#  'Ricardo Lemvo': ['afrobeat fusion'],
#  'Pompi': ['christian afrobeat',
#   'zambian gospel',
#   'zambian hip hop',
#   'zambian pop'],
#  'Sonny Okosun': ['african reggae', 'afrobeat', 'highlife'],
#  'Sunny Neji': ['afrobeats', 'naija old school'],
#  'Matata': ['afro psych', 'afrobeat'],
#  'Eclipse Nkasi': ['christian afrobeat'],
#  'Davolee': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Onipa': ['afrobeat fusion', 'afrofuturism'],
#  'Keleketla!': ['afrobeat fusion'],
#  'Victor Olaiya': ['afrobeat', 'highlife'],
#  '24ldz': ['christian afrobeat'],
#  'Manuel The Creator': ['christian afrobeat'],
#  'Metá Metá': ['brazilian indie',
#   'latin afrobeat',
#   'nova mpb',
#   'nova musica paulista'],
#  'Agent Snypa': ['christian afrobeat'],
#  'Newen Afrobeat': ['latin afrobeat'],
#  'Del B': ['afrobeats', 'igbo pop', 'nigerian pop'],
#  'Oyije': ['christian afrobeat'],
#  'Thiago França': ['afrobeat brasileiro',
#   'brass band brasileiro',
#   'brazilian indie',
#   'nova mpb'],
#  'African China': ['african reggae',
#   'afrobeats',
#   'naija old school',
#   'nigerian pop'],
#  'Darey': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Chief Obi': ['afrobeats', 'nigerian pop'],
#  'Keche': ['afrobeats', 'azonto', 'hiplife'],
#  'Son Palenque': ['cumbia',
#   'cumbia funk',
#   'folclor colombiano',
#   'latin afrobeat'],
#  'DJ Jimmy Jatt': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Bang Data': ['latin afrobeat', 'latinx alternative'],
#  'Ealle': ['christian afrobeat'],
#  'Waconzy': ['afrobeats'],
#  'Drumz': ['afrobeats'],
#  'Iconili': ['afrobeat brasileiro', 'latin afrobeat'],
#  'Nigel Lewis': ['christian afrobeat'],
#  'Kefee': ['afrobeats', 'christian afrobeat', 'naija old school'],
#  'Shay Dee': ['afrobeats', 'nigerian pop'],
#  'The Polyversal Souls': ['afrobeat fusion'],
#  'Los Pirañas': ['latin afrobeat'],
#  'King Edi K': ['latin afrobeat'],
#  'Drakare': ['christian afrobeat'],
#  'Idowest': ['afro drill',
#   'afrobeats',
#   'cruise',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Rikki Ililonga': ['afro psych', 'classic afrobeat'],
#  'Yung6ix': ['afrobeats', 'afropop', 'nigerian hip hop', 'nigerian pop'],
#  'Star Feminine Band': ['afrobeat fusion'],
#  'CSO': ['christian afrobeat'],
#  'Thabang Tabane': ['afrobeat fusion'],
#  'Illbliss': ['afrobeats', 'igbo rap', 'nigerian hip hop', 'nigerian pop'],
#  'Tjsarx': ['christian afrobeat'],
#  'El Hijo De La Cumbia': ['latin afrobeat', 'nu-cumbia'],
#  'Koker': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Eedris Abdulkareem': ['afrobeats',
#   'naija old school',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Efosa': ['afrobeats'],
#  'Victor Rice': ['latin afrobeat', 'ska jazz', 'traditional ska'],
#  "Aigbeh D'gong": ['christian afrobeat'],
#  'Mikeb': ['christian afrobeat'],
#  'Black Mantra': ['afrobeat brasileiro'],
#  'Soltune': ['christian afrobeat'],
#  'Nomade Orquestra': ['afrobeat brasileiro',
#   'afrofuturismo brasileiro',
#   'brass band brasileiro',
#   'latin afrobeat'],
#  'Victizzle': ['christian afrobeat'],
#  'Tony Allen & Jeff Mills': ['afrobeat fusion'],
#  'Supergombo': ['afrobeat fusion'],
#  'Klever Jay': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Raúl Monsalve y los Forajidos': ['afrobeat fusion', 'caracas indie'],
#  'Ilover': ['christian afrobeat', 'louange'],
#  'Street Church Music': ['christian afrobeat'],
#  'GK Moe': ['christian afrobeat'],
#  'Cabo Snoop': ['afrobeats', 'semba'],
#  'Eldee': ['afrobeats', 'naija old school', 'nigerian pop'],
#  'Wganda Kenya': ['champeta', 'cumbia', 'latin afrobeat'],
#  'Azarel': ['christian afrobeat'],
#  'LC Beatz': ['christian afrobeat'],
#  'Miklez': ['christian afrobeat'],
#  'Lynxxx': ['afrobeats', 'afropop', 'naija old school', 'nigerian pop'],
#  'Fatai Rolling Dollar': ['afrobeat', 'highlife', 'juju'],
#  'Fanga': ['afrobeat'],
#  'Rayce': ['afrobeats', 'naija old school', 'nigerian pop'],
#  'Tony Tetuila': ['afrobeats', 'naija old school', 'nigerian pop'],
#  "Gilles Peterson's Havana Cultura Band": ['cuban alternative',
#   'latin afrobeat'],
#  'The Funk Ark': ['afro-funk', 'afrobeat', 'bboy'],
#  'La Cumbia Chicharra': ['latin afrobeat'],
#  'Quiz Tha Great': ['christian afrobeat'],
#  'Geraldo Pino': ['afro psych', 'afrobeat'],
#  'Isaac Bola': ['african gospel', 'christian afrobeat'],
#  'Kingzkid': ['christian afrobeat'],
#  'Morbo y Mambo': ['argentine indie', 'latin afrobeat'],
#  'Niyola': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Kelly Hansome': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Thee Commons': ['latin afrobeat'],
#  'IFÁ': ['afrobeat brasileiro'],
#  'Big Ty': ['christian afrobeat'],
#  'Defayo': ['christian afrobeat'],
#  'Maga Bo': ['afrobeat brasileiro', 'afrofuturismo brasileiro'],
#  'Buyepongo': ['latin afrobeat', 'latinx alternative'],
#  'Cynthia Morgan': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Tunji Oyelana': ['afrobeat', 'classic afrobeat'],
#  'EbzyPraise': ['christian afrobeat'],
#  'Seletores de Frequência': ['afrobeat brasileiro'],
#  'DJ Shabsy': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Same OG': ['christian afrobeat', 'gospel amapiano'],
#  'La Misa Negra': ['latin afrobeat', 'latinx alternative'],
#  'Ikechukwu': ['afrobeats', 'igbo pop', 'naija old school', 'nigerian pop'],
#  'Afro Cult Foundation': ['classic afrobeat'],
#  'Shalini': ['christian afrobeat'],
#  'Durella': ['afrobeats',
#   'naija old school',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Kokolo': ['afrobeat', 'bboy', 'instrumental funk'],
#  'Chicago Afrobeat Project': ['afrobeat'],
#  'Afrodizz': ['afrobeat'],
#  'Hedzoleh Soundz': ['classic afrobeat', 'highlife'],
#  'Bongos Ikwue': ['afrobeat', 'classic afrobeat', 'highlife'],
#  'Vincent Ahehehinnou': ['beninese pop', 'classic afrobeat'],
#  'Oscar Sulley': ['afrobeat'],
#  'MayD': ['afrobeats'],
#  'Djinee': ['afrobeats', 'naija old school', 'nigerian pop'],
#  'The Tony Benson Sextet': ['classic afrobeat'],
#  'Kiko Dinucci e Bando Afro Macarrônico': ['afrobeat brasileiro'],
#  'Camarão Orkestra': ['afrobeat brasileiro'],
#  'Plantashun Boiz': ['afrobeats',
#   'afropop',
#   'nigerian hip hop',
#   'nigerian pop'],
#  'Battle of Santiago': ['canadian latin',
#   'canadian post-rock',
#   'latin afrobeat'],
#  'Eazzy': ['afrobeats', 'azonto', 'hiplife'],
#  'Lord Of Ajasa': ['afrobeats', 'nigerian hip hop', 'nigerian pop'],
#  'Orquestra Brasileira de Música Jamaicana': ['afrobeat brasileiro',
#   'brass band brasileiro',
#   'brazilian ska'],
#  'Kng James': ['christian afrobeat'],
#  'K.O.F.I': ['christian afrobeat'],
#  'MikeSolo': ['christian afrobeat'],
#  'Sauce Kid': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Samklef': ['afrobeats', 'afropop', 'nigerian pop'],
#  'Jaij Hollands': ['afrobeats'],
#  'Ezi Emela': ['afrobeats'],
#  'Samuca e a Selva': ['latin afrobeat'],
#  'The Anansa Professionals': ['classic afrobeat'],
#  'Ras Kimono': ['afrobeat', 'highlife'],
#  'Kwame Angelo': ['christian afrobeat'],
#  'Jlyricz': ['christian afrobeat'],
#  'Ofo The Black Company': ['classic afrobeat'],
#  'The Barbecues': ['classic afrobeat'],
#  'Mimi': ['christian afrobeat'],
#  'WeAreTheNew': ['christian afrobeat'],
#  'Sweet Talks': ['classic afrobeat', 'highlife'],
#  'Money Chicha': ['chicha', 'latin afrobeat'],
#  'Afrocidade': ['afrobeat brasileiro', 'afrofuturismo brasileiro'],
#  'Caê': ['afrobeat brasileiro', 'afrofuturismo brasileiro'],
#  'Linkin Park': ['alternative metal',
#   'modern rock',
#   'nu metal',
#   'post-grunge',
#   'rap metal',
#   'rock'],
#  'The Neighbourhood': ['modern alternative rock',
#   'modern rock',
#   'pop',
#   'pov: indie'],
#  ...}

# %%
len(artist_genres)
# Out:
# 35352

# %%
ag_df = pd.DataFrame({'Artist':artist_genres.keys(),'Genres':artist_genres.values()})
ag_df.head()
# Out:
#             Artist                                             Genres
# 0       Jason Mraz         [acoustic pop, dance pop, neo mellow, pop]
# 1  The Paper Kites  [acoustic pop, australian indie folk, indie fo...
# 2   Brandi Carlile  [acoustic pop, ectofolk, folk, lilith, modern ...
# 3   Ray LaMontagne  [acoustic pop, indie folk, neo mellow, stomp a...
# 4     Zack Tabudlo                         [acoustic opm, opm, p-pop]

# %% [markdown]
# Now that we've collected our data, lets move it into our database for permanent storage

# %%
conn_string = f'postgresql://postgres:{DB_PASS}@127.0.0.1/{DB_NAME}'
  
db = create_engine(conn_string)
conn = db.connect()
conn1 = psycopg2.connect(
    database=DB_NAME,
    user='postgres', 
    password=DB_PASS, 
    host='127.0.0.1', 
    port= '5432'
)
  
conn1.autocommit = True
cursor = conn1.cursor()

cursor.execute('DROP TABLE IF EXISTS artists_genres_data;')
  
sql_cmd = 'CREATE TABLE artists_genres_data('+\
      'artist TEXT,'+\
      'genres TEXT[]);'
  
cursor.execute(sql_cmd)
ag_df.to_sql('artists_genres_data',db,if_exists='replace')


conn1.commit()
conn1.close()

# %% [markdown]
# Now that data collection is finished, we can move onto the EDA process
